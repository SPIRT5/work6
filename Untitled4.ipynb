# %% [markdown]
# <a href="https://colab.research.google.com/github/SPIRT5/work6/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Известно, что генеральная совокупность распределена нормально со средним квадратическим отклонением, равным 16. Найти доверительный интервал для оценки математического ожидания a с надежностью 0.95, если выборочная средняя M = 80, а объем выборки n = 256.

# %% [markdown]
# Для нахождения доверительного интервала для математического ожидания
# 𝜇
# μ при известном стандартном отклонении
# 𝜎
# σ и нормальном распределении генеральной совокупности, используется следующая формула:
#
# Xˉ±Z/2(σ/кореньn)
#
# Посчитаем стандартную ошибку среднего:
#
# SE= σ/кореньn = 16/корень256=16/16=1
#
# Теперь можно найти доверительный интервал:
#
# Xˉ±Z α/2⋅SE=80±1.96⋅1
#
# Это дает:80−1.96≤μ≤80+1.96,
# 78.04≤μ≤81.96
#
# Таким образом, доверительный интервал для оценки математического ожидания с надежностью 0.95 равен [78.04;81.96].

# %% [markdown]
# В результате 10 независимых измерений некоторой величины X, выполненных с одинаковой точностью, получены опытные данные: 6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1 Предполагая, что результаты измерений подчинены нормальному закону распределения вероятностей, оценить истинное значение величины X при помощи доверительного интервала, покрывающего это значение с доверительной вероятностью 0,95.

# %% [markdown]
# Вычислим выборочное среднее Xˉ и выборочное стандартное отклонение 𝑠
#
#
# Xˉ= 1/n∑n i=1 X i
#
# s=корень n−1/1∑ n i=1(Xi− Xˉ) 2
#
# Где
# n=10
#
# Найдем выборочное среднее
# X= 10/(6.9+6.1+6.2+6.8+7.5+6.3+6.4+6.9+6.7+6.1) =6.59
#
# Вычислим выборочное стандартное отклонение
# s= корень(1.829/9)≈ корень 0.2032≈0.45
#
# Найдем критическое значение t для α=0.05 и 9 степеней свободы. Используем значение из таблицы распределения Стьюдента:
# t 0.025,9≈2.262
#
# Построим доверительный интервал:
# 6.59±2.262⋅0.142
# 6.59±0.321
# Таким образом, 95%-ый доверительный интервал для истинного значения величины X
# [6.27;6.91].

# %% [markdown]
# 3.Рост дочерей 175, 167, 154, 174, 178, 148, 160, 167, 169, 170 Рост матерей  178, 165, 165, 173, 168, 155, 160, 164, 178, 175 Используя эти данные построить 95% доверительный интервал для разности среднего роста родителей и детей.

# %% [markdown]
# Вычислим выборочные средние
# X1= 10/(175+167+154+174+178+148+160+167+169+170)=166.2
# X2= 10/(178+165+165+173+168+155+160+164+178+175)=168.1
#
# Вычислим выборочные стандартные отклонения ( s1 и s2):
# s1≈8.60
#
# s2≈6.95
#
# Найдем критическое значение
# t α=0.05 и 18 степеней свободы (
# n1+n 2−2=10+10−2):
#
# t 0.025,18 ≈2.101
#
# Построим доверительный интервал для разности средних:
#
# −1.9±2.101⋅ корень(7.396+4.83)
#
# −1.9±7.34
#
# Таким образом, 95%-ый доверительный интервал для разности среднего роста родителей и детей равен [−9.24;5.44].
